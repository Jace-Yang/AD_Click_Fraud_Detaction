# %%
# Load all helper function
# %run -i 'source.py'

# %% [markdown]
# # Preparation

# %% [markdown]
# # Feature Engineering

# %%
train = pd.read_feather("../processing/train_raw.feather")

# %% [markdown]
# - We only use 1 day! But it's enough to generate insights!

# %% [markdown]
# ## Time stamp

# %%
# Transformed it into local time in China. 
train['click_time'] = train['click_time'] + timedelta(hours=8)

# %%
# To Prototype we downsize the data
train = train[train['click_time'].dt.day == 8]

# %%
# Add day, hour, and minute
dt = train['click_time'].dt
train['day_of_week'] = dt.dayofweek
train['day'] = dt.day.astype('uint8')
train['hour'] = dt.hour.astype('uint8')
train['minute'] = dt.minute.astype('uint8')

# %% [markdown]
# ## Click amount and conversion rate to download

# %%
for group in tqdm([['ip'],
                   ['app'],
                   ['device'],
                   ['os'],
                   ['channel'],
                   ['hour'],
                   ['app', 'channel'],
                   ['ip', 'hour'],
                   ['ip', 'device', 'app'],
                   ['ip', 'device', 'os'],
                   ['ip', 'device', 'os', 'hour']]):
    feature_suffix = '_'.join(group)
    train['click_freq_by_' + feature_suffix] = train.groupby(group)['click_time'].transform('count').astype('int')
    # train['download_freq_by_' + feature_suffix] = train.groupby(group)['is_attributed'].transform('sum').astype('int') # download times by ip
    download_freq = train.groupby(group)['is_attributed'].transform('sum').astype('int') # download times by ip
    train['download_rate_by_' + feature_suffix] = download_freq / train['click_freq_by_' + feature_suffix]
# Out:
# 100%|██████████| 11/11 [01:32<00:00,  8.43s/it]

# %%
train = reduce_mem_usage(train)
# Out:
# -------------------Begin downsizing--------------------
# ip converted from int32 to int32
# app converted from int16 to int16
# device converted from int16 to int16
# os converted from int16 to int16
# channel converted from int16 to int16
# day_of_week converted from int64 to int8
# click_freq_by_ip converted from int64 to int32
# download_rate_by_ip converted from float64 to float16
# click_freq_by_app converted from int64 to int32
# download_rate_by_app converted from float64 to float16
# click_freq_by_device converted from int64 to int32
# download_rate_by_device converted from float64 to float16
# click_freq_by_os converted from int64 to int32
# download_rate_by_os converted from float64 to float16
# click_freq_by_channel converted from int64 to int32
# download_rate_by_channel converted from float64 to float16
# click_freq_by_hour converted from int64 to int32
# download_rate_by_hour converted from float64 to float16
# click_freq_by_app_channel converted from int64 to int32
# download_rate_by_app_channel converted from float64 to float16
# click_freq_by_ip_hour converted from int64 to int16
# download_rate_by_ip_hour converted from float64 to float16
# click_freq_by_ip_device_app converted from int64 to int32
# download_rate_by_ip_device_app converted from float64 to float16
# click_freq_by_ip_device_os converted from int64 to int32
# download_rate_by_ip_device_os converted from float64 to float16
# click_freq_by_ip_device_os_hour converted from int64 to int16
# download_rate_by_ip_device_os_hour converted from float64 to float16
# ------------------------Result-------------------------
#  -> Mem. usage decreased from 13.01 GB to 5.98 GB
# -------------------Finish downsizing-------------------

# %% [markdown]
# ## Unique values from group

# %%
# Looping features like train['nunique_channel_per_ip'] = train.groupby(['ip'])['channel'].transform('nunique')
for group, counted in tqdm([(['ip'], ['channel']),
                           (['ip'], ['device']),
                           (['ip'], ['app']),
                           (['ip'], ['os']),
                           (['app'], ['channel'])]):
    group_suffix = '_'.join(group)
    counted_suffix = '_'.join(counted)
    train['nunique_' + counted_suffix + '_per_' + group_suffix] = train.groupby(group_suffix)[counted_suffix].transform('nunique')
# Out:
# 100%|██████████| 5/5 [01:53<00:00, 22.68s/it]

# %% [markdown]
# ## Click Pattern

# %% [markdown]
# ```python
# # This feature takes some time to run, and need some missing value handling job!
#
# train.sort_values(by = "click_time", ascending=True, ignore_index=True, inplace=True)
# train['gap_last_click'] = train['click_time'] - train.groupby(['ip', 'device', 'os'])['click_time'].transform(lambda x: x.shift(1))
# train = train.dropna(subset=['gap_last_click']).reset_index(drop=True)
# train['gap_last_click'] = train['gap_last_click'].dt.seconds
# ```
#
# - This `gap_last_click` feature is important!! But we can test how to handle it's missing for initial click, which leads to download sometimes for real user. We should discuss this when we are doing modeling part!
#
# - Right now, we just move on

# %%
train = reduce_mem_usage(train)
# Out:
# -------------------Begin downsizing--------------------
# ip converted from int32 to int32
# app converted from int16 to int16
# device converted from int16 to int16
# os converted from int16 to int16
# channel converted from int16 to int16
# click_freq_by_ip converted from int32 to int32
# download_rate_by_ip converted from float16 to float16
# click_freq_by_app converted from int32 to int32
# download_rate_by_app converted from float16 to float16
# click_freq_by_device converted from int32 to int32
# download_rate_by_device converted from float16 to float16
# click_freq_by_os converted from int32 to int32
# download_rate_by_os converted from float16 to float16
# click_freq_by_channel converted from int32 to int32
# download_rate_by_channel converted from float16 to float16
# click_freq_by_hour converted from int32 to int32
# download_rate_by_hour converted from float16 to float16
# click_freq_by_app_channel converted from int32 to int32
# download_rate_by_app_channel converted from float16 to float16
# click_freq_by_ip_hour converted from int16 to int16
# download_rate_by_ip_hour converted from float16 to float16
# click_freq_by_ip_device_app converted from int32 to int32
# download_rate_by_ip_device_app converted from float16 to float16
# click_freq_by_ip_device_os converted from int32 to int32
# download_rate_by_ip_device_os converted from float16 to float16
# click_freq_by_ip_device_os_hour converted from int16 to int16
# download_rate_by_ip_device_os_hour converted from float16 to float16
# nunique_channel_per_ip converted from int64 to int16
# nunique_device_per_ip converted from int64 to int16
# nunique_app_per_ip converted from int64 to int16
# nunique_os_per_ip converted from int64 to int16
# nunique_channel_per_app converted from int64 to int8
# ------------------------Result-------------------------
#  -> Mem. usage decreased from 8.31 GB to 6.5 GB
# -------------------Finish downsizing-------------------

# %% [markdown]
# ## Save the output

# %%
train = train.reset_index(drop=True)

# %%
train.to_feather("../processing/train_with_feature.feather")

# %% [markdown]
# # Generate Feature for unseen data

# %%
unseen_data = pd.read_feather("../processing/test_raw.feather")
unseen_data['click_time'] = unseen_data['click_time'] + timedelta(hours=8)
unseen_data['hour'] = unseen_data['click_time'].dt.hour.astype('uint8')

# %%
unseen_data
# Out:
#           click_id      ip  app  device  os  channel          click_time  hour
# 0                0    5744    9       1   3      107 2017-11-10 12:00:00    12
# 1                1  119901    9       1   3      466 2017-11-10 12:00:00    12
# 2                2   72287   21       1  19      128 2017-11-10 12:00:00    12
# 3                3   78477   15       1  13      111 2017-11-10 12:00:00    12
# 4                4  123080   12       1  13      328 2017-11-10 12:00:00    12
# ...            ...     ...  ...     ...  ..      ...                 ...   ...
# 18790464  18790464   99442    9       1  13      127 2017-11-10 23:00:00    23
# 18790465  18790465   88046   23       1  37      153 2017-11-10 23:00:00    23
# 18790466  18790467   81398   18       1  17      265 2017-11-10 23:00:00    23
# 18790467  18790466  123236   27       1  13      122 2017-11-10 23:00:00    23
# 18790468  18790468   73516   12       2  27      265 2017-11-10 23:00:00    23
#
# [18790469 rows x 8 columns]

# %% [markdown]
# Nevigate the feature from the exsiting data usint 5 rules:

# %% [markdown]
# ## Fully-map

# %% [markdown]
# > Use `["ip", "app", "device", "os", "channel","hour"]` to locate features in exsiting dataset.

# %%
dataset = pd.read_feather("../processing/train_with_feature.feather")

# %%
ids = ["ip","app","device","os","channel"]
time_feature = ["hour"]
numc_features = ['click_freq_by_ip',
                 'download_rate_by_ip',
                 'click_freq_by_app',
                 'download_rate_by_app',
                 'click_freq_by_device',
                 'download_rate_by_device',
                 'click_freq_by_os',
                 'download_rate_by_os',
                 'click_freq_by_channel',
                 'download_rate_by_channel',
                 'click_freq_by_hour',
                 'download_rate_by_hour',
                 'click_freq_by_app_channel',
                 'download_rate_by_app_channel',
                 'click_freq_by_ip_hour',
                 'download_rate_by_ip_hour',
                 'click_freq_by_ip_device_app',
                 'download_rate_by_ip_device_app',
                 'click_freq_by_ip_device_os',
                 'download_rate_by_ip_device_os',
                 'click_freq_by_ip_device_os_hour',
                 'download_rate_by_ip_device_os_hour',
                 'nunique_channel_per_ip',
                 'nunique_device_per_ip',
                 'nunique_app_per_ip',
                 'nunique_os_per_ip',
                 'nunique_channel_per_app']
dataset_feature = dataset[ids + time_feature + numc_features]

# %%
#dataset_feature_pure = dataset_feature.sample(n = 100000).drop_duplicates(subset=ids+time_feature, keep="first")
dataset_feature_pure = dataset_feature.drop_duplicates(subset=ids+time_feature, keep="first")

# %%
unseen_data_binded = unseen_data.merge(dataset_feature_pure, how = "left", indicator = True)

# %%
unseen_data_binded_exist_1 = unseen_data_binded.loc[unseen_data_binded["_merge"] == "both"].drop(labels='_merge', axis=1)
unseen_data_binded_exist_1
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 2                2   72287   21       1  19      128 2017-11-10 12:00:00
# 11              11  111025    3       1  19      137 2017-11-10 12:00:00
# 24              24   48240   18       1  42      107 2017-11-10 12:00:00
# 27              27  114220    9       1  13      445 2017-11-10 12:00:00
# 39              39    5429   12       1  19      265 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 18790448  18790448   25553    2       1  22      205 2017-11-10 23:00:00
# 18790449  18790449  119531   21       2  19      128 2017-11-10 23:00:00
# 18790459  18790459  102467   15       1  17      140 2017-11-10 23:00:00
# 18790465  18790465   88046   23       1  37      153 2017-11-10 23:00:00
# 18790468  18790468   73516   12       2  27      265 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 2           12        5103.00000              0.00118  ...
# 11          12       74629.00000              0.00042  ...
# 24          12       51025.00000              0.00033  ...
# 27          12       50927.00000              0.00004  ...
# 39          12         649.00000              0.00308  ...
# ...        ...               ...                  ...  ...
# 18790448    23       14863.00000              0.00067  ...
# 18790449    23       70473.00000              0.00121  ...
# 18790459    23       12967.00000              0.00224  ...
# 18790465    23        3125.00000              0.00160  ...
# 18790468    23      270511.00000              0.00127  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 2                                0.00000                  1490.00000
# 11                               0.00023                 16636.00000
# 24                               0.00000                   270.00000
# 27                               0.00000                 10550.00000
# 39                               0.00000                   143.00000
# ...                                  ...                         ...
# 18790448                         0.00000                   789.00000
# 18790449                         0.00000                  1746.00000
# 18790459                         0.00000                   388.00000
# 18790465                         0.00000                   170.00000
# 18790468                         0.00000                   748.00000
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 2                               0.00201                        104.00000
# 11                              0.00024                        854.00000
# 24                              0.00000                          8.00000
# 27                              0.00000                        437.00000
# 39                              0.00000                         14.00000
# ...                                 ...                              ...
# 18790448                        0.00380                         47.00000
# 18790449                        0.00057                         35.00000
# 18790459                        0.00000                         46.00000
# 18790465                        0.00000                         28.00000
# 18790468                        0.00000                         72.00000
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 2                                    0.00000               114.00000
# 11                                   0.00000               140.00000
# 24                                   0.00000               127.00000
# 27                                   0.00000               132.00000
# 39                                   0.00000                79.00000
# ...                                      ...                     ...
# 18790448                             0.00000               108.00000
# 18790449                             0.00000               133.00000
# 18790459                             0.00000               114.00000
# 18790465                             0.00000               107.00000
# 18790468                             0.00000               139.00000
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 2                       7.00000            52.00000           44.00000
# 11                     38.00000           113.00000          104.00000
# 24                     21.00000            94.00000          121.00000
# 27                     38.00000           115.00000           96.00000
# 39                      6.00000            33.00000           35.00000
# ...                         ...                 ...                ...
# 18790448                5.00000            49.00000           70.00000
# 18790449               44.00000           115.00000           91.00000
# 18790459                9.00000            55.00000           68.00000
# 18790465                7.00000            52.00000           48.00000
# 18790468               58.00000           138.00000          150.00000
#
#           nunique_channel_per_app
# 2                         8.00000
# 11                       45.00000
# 24                       18.00000
# 27                       39.00000
# 39                       33.00000
# ...                           ...
# 18790448                 26.00000
# 18790449                  8.00000
# 18790459                 30.00000
# 18790465                  8.00000
# 18790468                 33.00000
#
# [2950112 rows x 35 columns]

# %%
unseen_data_binded_new_1 = unseen_data_binded.loc[unseen_data_binded["_merge"] == "left_only"].drop(labels='_merge', axis=1)
unseen_data_binded_new_1
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 0                0    5744    9       1   3      107 2017-11-10 12:00:00
# 1                1  119901    9       1   3      466 2017-11-10 12:00:00
# 3                3   78477   15       1  13      111 2017-11-10 12:00:00
# 4                4  123080   12       1  13      328 2017-11-10 12:00:00
# 5                5  110769   18       1  13      107 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 18790462  18790461  113418   17       1  17      128 2017-11-10 23:00:00
# 18790463  18790463   69245   12       1  13      135 2017-11-10 23:00:00
# 18790464  18790464   99442    9       1  13      127 2017-11-10 23:00:00
# 18790466  18790467   81398   18       1  17      265 2017-11-10 23:00:00
# 18790467  18790466  123236   27       1  13      122 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 0           12               NaN                  NaN  ...
# 1           12               NaN                  NaN  ...
# 3           12               NaN                  NaN  ...
# 4           12               NaN                  NaN  ...
# 5           12               NaN                  NaN  ...
# ...        ...               ...                  ...  ...
# 18790462    23               NaN                  NaN  ...
# 18790463    23               NaN                  NaN  ...
# 18790464    23               NaN                  NaN  ...
# 18790466    23               NaN                  NaN  ...
# 18790467    23               NaN                  NaN  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
# 5                                    NaN                         NaN
# ...                                  ...                         ...
# 18790462                             NaN                         NaN
# 18790463                             NaN                         NaN
# 18790464                             NaN                         NaN
# 18790466                             NaN                         NaN
# 18790467                             NaN                         NaN
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# 5                                   NaN                              NaN
# ...                                 ...                              ...
# 18790462                            NaN                              NaN
# 18790463                            NaN                              NaN
# 18790464                            NaN                              NaN
# 18790466                            NaN                              NaN
# 18790467                            NaN                              NaN
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 3                                        NaN                     NaN
# 4                                        NaN                     NaN
# 5                                        NaN                     NaN
# ...                                      ...                     ...
# 18790462                                 NaN                     NaN
# 18790463                                 NaN                     NaN
# 18790464                                 NaN                     NaN
# 18790466                                 NaN                     NaN
# 18790467                                 NaN                     NaN
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                           NaN                 NaN                NaN
# 1                           NaN                 NaN                NaN
# 3                           NaN                 NaN                NaN
# 4                           NaN                 NaN                NaN
# 5                           NaN                 NaN                NaN
# ...                         ...                 ...                ...
# 18790462                    NaN                 NaN                NaN
# 18790463                    NaN                 NaN                NaN
# 18790464                    NaN                 NaN                NaN
# 18790466                    NaN                 NaN                NaN
# 18790467                    NaN                 NaN                NaN
#
#           nunique_channel_per_app
# 0                             NaN
# 1                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# ...                           ...
# 18790462                      NaN
# 18790463                      NaN
# 18790464                      NaN
# 18790466                      NaN
# 18790467                      NaN
#
# [15840357 rows x 35 columns]

# %% [markdown]
# ## Locate feature without time

# %% [markdown]
# > Use `["ip", "app", "device", "os", "channel"]` to locate features in exsiting dataset.

# %%
temp = unseen_data_binded_new_1[["click_id","ip", "app", "device", "os", "channel","click_time", "hour"]].merge(dataset_feature_pure.drop(labels='hour', axis=1), 
                                                                                                                on=["ip", "app", "device", "os", "channel"], 
                                                                                                                how="left", 
                                                                                                                indicator = True)

# %%
unseen_data_binded_exist_2 = temp.loc[temp["_merge"] == "both"].drop(labels='_merge', axis=1)
unseen_data_binded_exist_2 = unseen_data_binded_exist_2.groupby(["click_id","ip", "app", "device", "os", "channel","hour"], as_index=False).mean()
unseen_data_binded_exist_2
# Out:
#          click_id      ip  app  device  os  channel  hour  click_freq_by_ip  \
# 0               3   78477   15       1  13      111    12        4201.00000
# 1               5  110769   18       1  13      107    12        1346.00000
# 2               7   88637   27       1  19      153    12        1774.00000
# 3               9   14932   18       1  10      107    12        2428.00000
# 4              12   16050   12       1  13      265    12        1709.00000
# ...           ...     ...  ...     ...  ..      ...   ...               ...
# 5673241  18790440   14334   14       1  19      401    23        1264.00000
# 5673242  18790447   66176    1       1  19      125    23        4971.00000
# 5673243  18790456  100697    8       1  18      259    23        1038.00000
# 5673244  18790458   85329    2       1  14      452    23       23839.00000
# 5673245  18790462  101214    2       2  16      237    23       16760.00000
#
#          download_rate_by_ip  click_freq_by_app  ...  \
# 0                    0.00238      5603385.00000  ...
# 1                    0.00074      5090081.00000  ...
# 2                    0.00056       427276.00000  ...
# 3                    0.00041      5090081.00000  ...
# 4                    0.00059      8408754.00000  ...
# ...                      ...                ...  ...
# 5673241              0.00158      3347339.00000  ...
# 5673242              0.00040      1968988.00000  ...
# 5673243              0.00193       946411.00000  ...
# 5673244              0.00180      7366228.00000  ...
# 5673245              0.00090      7366228.00000  ...
#
#          download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                               0.00000                   921.00000
# 1                               0.00000                   276.00000
# 2                               0.00000                   393.00000
# 3                               0.00000                    23.00000
# 4                               0.00000                   191.00000
# ...                                 ...                         ...
# 5673241                         0.00000                   298.00000
# 5673242                         0.00000                  1063.00000
# 5673243                         0.00000                    57.00000
# 5673244                         0.00053                   242.00000
# 5673245                         0.00000                    29.00000
#
#          download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                              0.00326                         19.00000
# 1                              0.00000                         20.00000
# 2                              0.00000                         18.00000
# 3                              0.00000                          4.00000
# 4                              0.00000                          9.50000
# ...                                ...                              ...
# 5673241                        0.00000                         18.00000
# 5673242                        0.00094                          6.00000
# 5673243                        0.00000                         27.00000
# 5673244                        0.00000                         24.00000
# 5673245                        0.00000                          3.00000
#
#          download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                   0.00000               113.00000
# 1                                   0.00000               102.00000
# 2                                   0.00000                93.00000
# 3                                   0.00000               106.00000
# 4                                   0.00000                99.00000
# ...                                     ...                     ...
# 5673241                             0.00000                98.00000
# 5673242                             0.00000               106.00000
# 5673243                             0.00000                88.00000
# 5673244                             0.00000               130.00000
# 5673245                             0.00000               127.00000
#
#          nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                      5.00000            48.00000           43.00000
# 1                      5.00000            38.00000           35.00000
# 2                      4.00000            40.00000           38.00000
# 3                      3.00000            42.00000           39.00000
# 4                      4.00000            41.00000           33.00000
# ...                        ...                 ...                ...
# 5673241                4.00000            35.00000           36.00000
# 5673242                5.00000            43.00000           67.00000
# 5673243                5.00000            36.00000           44.00000
# 5673244               39.00000           102.00000           89.00000
# 5673245               30.00000            92.00000           88.00000
#
#          nunique_channel_per_app
# 0                       30.00000
# 1                       18.00000
# 2                        5.00000
# 3                       18.00000
# 4                       33.00000
# ...                          ...
# 5673241                 36.00000
# 5673242                 31.00000
# 5673243                  3.00000
# 5673244                 26.00000
# 5673245                 26.00000
#
# [5673246 rows x 34 columns]

# %%
unseen_data_binded_new_2 = temp.loc[temp["_merge"] == "left_only"].drop(labels='_merge', axis=1)
unseen_data_binded_new_2
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 0                0    5744    9       1   3      107 2017-11-10 12:00:00
# 1                1  119901    9       1   3      466 2017-11-10 12:00:00
# 3                4  123080   12       1  13      328 2017-11-10 12:00:00
# 7                6   12540    3       1   1      137 2017-11-10 12:00:00
# 10               8  123701   12       1  53      424 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 29191817  18790461  113418   17       1  17      128 2017-11-10 23:00:00
# 29191818  18790463   69245   12       1  13      135 2017-11-10 23:00:00
# 29191819  18790464   99442    9       1  13      127 2017-11-10 23:00:00
# 29191820  18790467   81398   18       1  17      265 2017-11-10 23:00:00
# 29191821  18790466  123236   27       1  13      122 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 0           12               NaN                  NaN  ...
# 1           12               NaN                  NaN  ...
# 3           12               NaN                  NaN  ...
# 7           12               NaN                  NaN  ...
# 10          12               NaN                  NaN  ...
# ...        ...               ...                  ...  ...
# 29191817    23               NaN                  NaN  ...
# 29191818    23               NaN                  NaN  ...
# 29191819    23               NaN                  NaN  ...
# 29191820    23               NaN                  NaN  ...
# 29191821    23               NaN                  NaN  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 3                                    NaN                         NaN
# 7                                    NaN                         NaN
# 10                                   NaN                         NaN
# ...                                  ...                         ...
# 29191817                             NaN                         NaN
# 29191818                             NaN                         NaN
# 29191819                             NaN                         NaN
# 29191820                             NaN                         NaN
# 29191821                             NaN                         NaN
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 3                                   NaN                              NaN
# 7                                   NaN                              NaN
# 10                                  NaN                              NaN
# ...                                 ...                              ...
# 29191817                            NaN                              NaN
# 29191818                            NaN                              NaN
# 29191819                            NaN                              NaN
# 29191820                            NaN                              NaN
# 29191821                            NaN                              NaN
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                        NaN                     NaN
# 1                                        NaN                     NaN
# 3                                        NaN                     NaN
# 7                                        NaN                     NaN
# 10                                       NaN                     NaN
# ...                                      ...                     ...
# 29191817                                 NaN                     NaN
# 29191818                                 NaN                     NaN
# 29191819                                 NaN                     NaN
# 29191820                                 NaN                     NaN
# 29191821                                 NaN                     NaN
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                           NaN                 NaN                NaN
# 1                           NaN                 NaN                NaN
# 3                           NaN                 NaN                NaN
# 7                           NaN                 NaN                NaN
# 10                          NaN                 NaN                NaN
# ...                         ...                 ...                ...
# 29191817                    NaN                 NaN                NaN
# 29191818                    NaN                 NaN                NaN
# 29191819                    NaN                 NaN                NaN
# 29191820                    NaN                 NaN                NaN
# 29191821                    NaN                 NaN                NaN
#
#           nunique_channel_per_app
# 0                             NaN
# 1                             NaN
# 3                             NaN
# 7                             NaN
# 10                            NaN
# ...                           ...
# 29191817                      NaN
# 29191818                      NaN
# 29191819                      NaN
# 29191820                      NaN
# 29191821                      NaN
#
# [10167111 rows x 35 columns]

# %% [markdown]
# ## Use ip+device to match features

# %% [markdown]
# > Use `["ip", "device"]` to locate features in exsiting dataset.

# %%
temp = unseen_data_binded_new_2[["click_id","ip", "app", "device", "os", "channel","click_time", "hour"]].merge(dataset_feature_pure.groupby(["ip", "device"], as_index=False)[numc_features].mean(),
                                                                                                                how="left", 
                                                                                                                indicator = True)

# %%
unseen_data_binded_exist_3 = temp.loc[temp["_merge"] == "both"].drop(labels='_merge', axis=1)
unseen_data_binded_exist_3
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 0                0    5744    9       1   3      107 2017-11-10 12:00:00
# 1                1  119901    9       1   3      466 2017-11-10 12:00:00
# 3                6   12540    3       1   1      137 2017-11-10 12:00:00
# 4                8  123701   12       1  53      424 2017-11-10 12:00:00
# 6               13   31555    9       1  13      244 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 10167099  18790451   48536   14       1  19      442 2017-11-10 23:00:00
# 10167102  18790455   55874    1       1  22      125 2017-11-10 23:00:00
# 10167106  18790461  113418   17       1  17      128 2017-11-10 23:00:00
# 10167107  18790463   69245   12       1  13      135 2017-11-10 23:00:00
# 10167109  18790467   81398   18       1  17      265 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 0           12         339.00000              0.00295  ...
# 1           12        7396.00000              0.00203  ...
# 3           12        1339.00000              0.00224  ...
# 4           12       10149.00000              0.00049  ...
# 6           12        1842.00000              0.00054  ...
# ...        ...               ...                  ...  ...
# 10167099    23         522.00000              0.00192  ...
# 10167102    23        3366.00000              0.00059  ...
# 10167106    23        4180.00000              0.00072  ...
# 10167107    23        1077.00000              0.00000  ...
# 10167109    23        3640.00000              0.00137  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                                0.00000                    27.10545
# 1                                0.00218                   752.53691
# 3                                0.00096                   182.88558
# 4                                0.00024                   926.52186
# 6                                0.00083                   201.48093
# ...                                  ...                         ...
# 10167099                         0.00217                    85.24000
# 10167102                         0.00072                   432.59630
# 10167106                         0.00054                   484.81758
# 10167107                         0.00000                   170.61538
# 10167109                         0.00143                   525.93625
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                               0.00000                          6.46182
# 1                               0.00155                         45.42412
# 3                               0.00073                         20.68365
# 4                               0.00017                         49.31823
# 6                               0.00036                         19.45108
# ...                                 ...                              ...
# 10167099                        0.00201                         16.92571
# 10167102                        0.00076                         36.38219
# 10167106                        0.00054                         33.90879
# 10167107                        0.00000                         19.34135
# 10167109                        0.00112                         35.69482
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                    0.00000                67.00000
# 1                                    0.00169               118.00000
# 3                                    0.00096                99.00000
# 4                                    0.00014               120.00000
# 6                                    0.00066               103.00000
# ...                                      ...                     ...
# 10167099                             0.00114                71.00000
# 10167102                             0.00092               104.00000
# 10167106                             0.00063               115.00000
# 10167107                             0.00000                88.00000
# 10167109                             0.00118               110.00000
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                       4.00000            27.00000           31.00000
# 1                      10.00000            63.00000           54.00000
# 3                       5.00000            39.00000           31.00000
# 4                      18.00000            52.00000           76.00000
# 6                       7.00000            42.00000           37.00000
# ...                         ...                 ...                ...
# 10167099                3.00000            28.00000           24.00000
# 10167102                6.00000            46.00000           52.00000
# 10167106                6.00000            53.00000           46.00000
# 10167107                2.00000            32.00000           31.00000
# 10167109                6.00000            45.00000           43.00000
#
#           nunique_channel_per_app
# 0                        28.10182
# 1                        28.12297
# 3                        28.06538
# 4                        27.82684
# 6                        27.70978
# ...                           ...
# 10167099                 28.30000
# 10167102                 28.44772
# 10167106                 28.13243
# 10167107                 28.18870
# 10167109                 28.08845
#
# [6097457 rows x 35 columns]

# %%
unseen_data_binded_new_3 = temp.loc[temp["_merge"] == "left_only"].drop(labels='_merge', axis=1)
unseen_data_binded_new_3
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 2                4  123080   12       1  13      328 2017-11-10 12:00:00
# 5               10  106056   26       1  19      477 2017-11-10 12:00:00
# 9               16  104009   18       1  17      107 2017-11-10 12:00:00
# 11              19   80209   27       1  13      122 2017-11-10 12:00:00
# 22              37  104791    6       1  13      459 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 10167103  18790454   93291    9       1  19      145 2017-11-10 23:00:00
# 10167104  18790457   93291   20       1  19      259 2017-11-10 23:00:00
# 10167105  18790460   80537    9       1  19      445 2017-11-10 23:00:00
# 10167108  18790464   99442    9       1  13      127 2017-11-10 23:00:00
# 10167110  18790466  123236   27       1  13      122 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 2           12               NaN                  NaN  ...
# 5           12               NaN                  NaN  ...
# 9           12               NaN                  NaN  ...
# 11          12               NaN                  NaN  ...
# 22          12               NaN                  NaN  ...
# ...        ...               ...                  ...  ...
# 10167103    23               NaN                  NaN  ...
# 10167104    23               NaN                  NaN  ...
# 10167105    23               NaN                  NaN  ...
# 10167108    23               NaN                  NaN  ...
# 10167110    23               NaN                  NaN  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 2                                    NaN                         NaN
# 5                                    NaN                         NaN
# 9                                    NaN                         NaN
# 11                                   NaN                         NaN
# 22                                   NaN                         NaN
# ...                                  ...                         ...
# 10167103                             NaN                         NaN
# 10167104                             NaN                         NaN
# 10167105                             NaN                         NaN
# 10167108                             NaN                         NaN
# 10167110                             NaN                         NaN
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 2                                   NaN                              NaN
# 5                                   NaN                              NaN
# 9                                   NaN                              NaN
# 11                                  NaN                              NaN
# 22                                  NaN                              NaN
# ...                                 ...                              ...
# 10167103                            NaN                              NaN
# 10167104                            NaN                              NaN
# 10167105                            NaN                              NaN
# 10167108                            NaN                              NaN
# 10167110                            NaN                              NaN
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 2                                        NaN                     NaN
# 5                                        NaN                     NaN
# 9                                        NaN                     NaN
# 11                                       NaN                     NaN
# 22                                       NaN                     NaN
# ...                                      ...                     ...
# 10167103                                 NaN                     NaN
# 10167104                                 NaN                     NaN
# 10167105                                 NaN                     NaN
# 10167108                                 NaN                     NaN
# 10167110                                 NaN                     NaN
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 2                           NaN                 NaN                NaN
# 5                           NaN                 NaN                NaN
# 9                           NaN                 NaN                NaN
# 11                          NaN                 NaN                NaN
# 22                          NaN                 NaN                NaN
# ...                         ...                 ...                ...
# 10167103                    NaN                 NaN                NaN
# 10167104                    NaN                 NaN                NaN
# 10167105                    NaN                 NaN                NaN
# 10167108                    NaN                 NaN                NaN
# 10167110                    NaN                 NaN                NaN
#
#           nunique_channel_per_app
# 2                             NaN
# 5                             NaN
# 9                             NaN
# 11                            NaN
# 22                            NaN
# ...                           ...
# 10167103                      NaN
# 10167104                      NaN
# 10167105                      NaN
# 10167108                      NaN
# 10167110                      NaN
#
# [4069654 rows x 35 columns]

# %% [markdown]
# ## Use Only ip to match feature

# %%
temp = unseen_data_binded_new_3[["click_id","ip", "app", "device", "os", "channel","click_time", "hour"]].merge(dataset_feature_pure.groupby(["ip"], as_index=False)[numc_features].mean(),
                                                                                                                how="left", 
                                                                                                                indicator = True)

# %%
unseen_data_binded_exist_4 = temp.loc[temp["_merge"] == "both"].drop(labels='_merge', axis=1)
unseen_data_binded_exist_4
# Out:
#          click_id     ip  app  device  os  channel          click_time  hour  \
# 77            398  19964   19      16   0      213 2017-11-10 12:00:00    12
# 184           927  48533  215       3  33      347 2017-11-10 12:00:01    12
# 200           990  19964   19      16   0      213 2017-11-10 12:00:01    12
# 318          1533  32480   97       3  33      347 2017-11-10 12:00:02    12
# 340          1628  63893    3       5  45      404 2017-11-10 12:00:02    12
# ...           ...    ...  ...     ...  ..      ...                 ...   ...
# 4069585  18790191  17977   21       2  10      232 2017-11-10 23:00:00    23
# 4069601  18790280  17977    9       2  10      134 2017-11-10 23:00:00    23
# 4069602  18790283  17977   12       2  10      145 2017-11-10 23:00:00    23
# 4069616  18790330    832   19     204  38      213 2017-11-10 23:00:00    23
# 4069628  18790361  63986   19     712  21      213 2017-11-10 23:00:00    23
#
#          click_freq_by_ip  download_rate_by_ip  ...  \
# 77             1930.00000              0.00052  ...
# 184            4895.00000              0.00102  ...
# 200            1930.00000              0.00052  ...
# 318            1247.00000              0.00160  ...
# 340            1100.00000              0.00182  ...
# ...                   ...                  ...  ...
# 4069585         934.00000              0.00107  ...
# 4069601         934.00000              0.00107  ...
# 4069602         934.00000              0.00107  ...
# 4069616        2201.00000              0.00182  ...
# 4069628        1701.00000              0.00059  ...
#
#          download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 77                              0.00069                   201.52831
# 184                             0.00111                   428.73205
# 200                             0.00069                   201.52831
# 318                             0.00206                    78.99236
# 340                             0.00233                   115.36205
# ...                                 ...                         ...
# 4069585                         0.00164                   115.14098
# 4069601                         0.00164                   115.14098
# 4069602                         0.00164                   115.14098
# 4069616                         0.00247                   324.39975
# 4069628                         0.00061                   170.49810
#
#          download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 77                             0.00050                         19.99793
# 184                            0.00102                         37.00339
# 200                            0.00050                         19.99793
# 318                            0.00148                          8.41703
# 340                            0.00204                         17.43073
# ...                                ...                              ...
# 4069585                        0.00164                         16.43934
# 4069601                        0.00164                         16.43934
# 4069602                        0.00164                         16.43934
# 4069616                        0.00191                         25.09932
# 4069628                        0.00051                         22.09520
#
#          download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 77                                  0.00059                97.00000
# 184                                 0.00129               106.00000
# 200                                 0.00059                97.00000
# 318                                 0.00111                88.00000
# 340                                 0.00233                93.00000
# ...                                     ...                     ...
# 4069585                             0.00164                91.00000
# 4069601                             0.00164                91.00000
# 4069602                             0.00164                91.00000
# 4069616                             0.00191                96.00000
# 4069628                             0.00038                95.00000
#
#          nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 77                     6.00000            39.00000           50.00000
# 184                   11.00000            51.00000           57.00000
# 200                    6.00000            39.00000           50.00000
# 318                    5.00000            33.00000           49.00000
# 340                    4.00000            37.00000           40.00000
# ...                        ...                 ...                ...
# 4069585                4.00000            36.00000           35.00000
# 4069601                4.00000            36.00000           35.00000
# 4069602                4.00000            36.00000           35.00000
# 4069616                5.00000            42.00000           35.00000
# 4069628                6.00000            44.00000           47.00000
#
#          nunique_channel_per_app
# 77                      28.02624
# 184                     27.48137
# 200                     28.02624
# 318                     29.05677
# 340                     28.32945
# ...                          ...
# 4069585                 28.91803
# 4069601                 28.91803
# 4069602                 28.91803
# 4069616                 28.45157
# 4069628                 28.11120
#
# [110643 rows x 35 columns]

# %%
unseen_data_binded_new_4 = temp.loc[temp["_merge"] == "left_only"].drop(labels='_merge', axis=1)
unseen_data_binded_new_4
# Out:
#          click_id      ip  app  device  os  channel          click_time  hour  \
# 0               4  123080   12       1  13      328 2017-11-10 12:00:00    12
# 1              10  106056   26       1  19      477 2017-11-10 12:00:00    12
# 2              16  104009   18       1  17      107 2017-11-10 12:00:00    12
# 3              19   80209   27       1  13      122 2017-11-10 12:00:00    12
# 4              37  104791    6       1  13      459 2017-11-10 12:00:00    12
# ...           ...     ...  ...     ...  ..      ...                 ...   ...
# 4069649  18790454   93291    9       1  19      145 2017-11-10 23:00:00    23
# 4069650  18790457   93291   20       1  19      259 2017-11-10 23:00:00    23
# 4069651  18790460   80537    9       1  19      445 2017-11-10 23:00:00    23
# 4069652  18790464   99442    9       1  13      127 2017-11-10 23:00:00    23
# 4069653  18790466  123236   27       1  13      122 2017-11-10 23:00:00    23
#
#          click_freq_by_ip  download_rate_by_ip  ...  \
# 0                     NaN                  NaN  ...
# 1                     NaN                  NaN  ...
# 2                     NaN                  NaN  ...
# 3                     NaN                  NaN  ...
# 4                     NaN                  NaN  ...
# ...                   ...                  ...  ...
# 4069649               NaN                  NaN  ...
# 4069650               NaN                  NaN  ...
# 4069651               NaN                  NaN  ...
# 4069652               NaN                  NaN  ...
# 4069653               NaN                  NaN  ...
#
#          download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 4069649                             NaN                         NaN
# 4069650                             NaN                         NaN
# 4069651                             NaN                         NaN
# 4069652                             NaN                         NaN
# 4069653                             NaN                         NaN
#
#          download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# ...                                ...                              ...
# 4069649                            NaN                              NaN
# 4069650                            NaN                              NaN
# 4069651                            NaN                              NaN
# 4069652                            NaN                              NaN
# 4069653                            NaN                              NaN
#
#          download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 4069649                                 NaN                     NaN
# 4069650                                 NaN                     NaN
# 4069651                                 NaN                     NaN
# 4069652                                 NaN                     NaN
# 4069653                                 NaN                     NaN
#
#          nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                          NaN                 NaN                NaN
# 1                          NaN                 NaN                NaN
# 2                          NaN                 NaN                NaN
# 3                          NaN                 NaN                NaN
# 4                          NaN                 NaN                NaN
# ...                        ...                 ...                ...
# 4069649                    NaN                 NaN                NaN
# 4069650                    NaN                 NaN                NaN
# 4069651                    NaN                 NaN                NaN
# 4069652                    NaN                 NaN                NaN
# 4069653                    NaN                 NaN                NaN
#
#          nunique_channel_per_app
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 4069649                      NaN
# 4069650                      NaN
# 4069651                      NaN
# 4069652                      NaN
# 4069653                      NaN
#
# [3959011 rows x 35 columns]

# %% [markdown]
# ## Provide an average result

# %%
avg_impute = pd.DataFrame({"mean":dataset_feature_pure[numc_features].mean()}).T
avg_impute = avg_impute.reset_index(drop=True)
avg_impute['join_id'] = 1
avg_impute
# Out:
# /root/miniconda3/envs/myconda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /root/miniconda3/envs/myconda/lib/python3.7/site-packages/numpy/core/_methods.py:47: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#    click_freq_by_ip  download_rate_by_ip  click_freq_by_app  \
# 0        8228.38139                  NaN      5996919.70222
#
#    download_rate_by_app  click_freq_by_device  download_rate_by_device  \
# 0                   NaN        56467485.84662                      NaN
#
#    click_freq_by_os  download_rate_by_os  click_freq_by_channel  \
# 0     6770754.33617                  NaN          1447331.24365
#
#    download_rate_by_channel  ...  click_freq_by_ip_device_os  \
# 0                       NaN  ...                   520.19583
#
#    download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                            NaN                         36.51880
#
#    download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                 NaN                98.54734
#
#    nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                8.27912            45.63491           44.08737
#
#    nunique_channel_per_app  join_id
# 0                 27.86215        1
#
# [1 rows x 28 columns]

# %%
temp = unseen_data_binded_new_4[["click_id","ip", "app", "device", "os", "channel","click_time", "hour"]]
temp['join_id'] = 1
temp
# Out:
#          click_id      ip  app  device  os  channel          click_time  hour  \
# 0               4  123080   12       1  13      328 2017-11-10 12:00:00    12
# 1              10  106056   26       1  19      477 2017-11-10 12:00:00    12
# 2              16  104009   18       1  17      107 2017-11-10 12:00:00    12
# 3              19   80209   27       1  13      122 2017-11-10 12:00:00    12
# 4              37  104791    6       1  13      459 2017-11-10 12:00:00    12
# ...           ...     ...  ...     ...  ..      ...                 ...   ...
# 4069649  18790454   93291    9       1  19      145 2017-11-10 23:00:00    23
# 4069650  18790457   93291   20       1  19      259 2017-11-10 23:00:00    23
# 4069651  18790460   80537    9       1  19      445 2017-11-10 23:00:00    23
# 4069652  18790464   99442    9       1  13      127 2017-11-10 23:00:00    23
# 4069653  18790466  123236   27       1  13      122 2017-11-10 23:00:00    23
#
#          join_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 4069649        1
# 4069650        1
# 4069651        1
# 4069652        1
# 4069653        1
#
# [3959011 rows x 9 columns]

# %%
unseen_data_newip = temp.merge(avg_impute, how="left").drop(labels='join_id', axis=1)

# %%
unseen_data_withfeature = pd.concat([unseen_data_binded_exist_1, unseen_data_binded_exist_2, unseen_data_binded_exist_3, unseen_data_binded_exist_4, unseen_data_newip], axis=0)

# %%
unseen_data_withfeature = unseen_data_withfeature.sort_values(by = "click_id").reset_index(drop=True)
unseen_data_withfeature
# Out:
#           click_id      ip  app  device  os  channel          click_time  \
# 0                0    5744    9       1   3      107 2017-11-10 12:00:00
# 1                1  119901    9       1   3      466 2017-11-10 12:00:00
# 2                2   72287   21       1  19      128 2017-11-10 12:00:00
# 3                3   78477   15       1  13      111                 NaT
# 4                4  123080   12       1  13      328 2017-11-10 12:00:00
# ...            ...     ...  ...     ...  ..      ...                 ...
# 18790464  18790464   99442    9       1  13      127 2017-11-10 23:00:00
# 18790465  18790465   88046   23       1  37      153 2017-11-10 23:00:00
# 18790466  18790466  123236   27       1  13      122 2017-11-10 23:00:00
# 18790467  18790467   81398   18       1  17      265 2017-11-10 23:00:00
# 18790468  18790468   73516   12       2  27      265 2017-11-10 23:00:00
#
#           hour  click_freq_by_ip  download_rate_by_ip  ...  \
# 0           12         339.00000              0.00295  ...
# 1           12        7396.00000              0.00203  ...
# 2           12        5103.00000              0.00118  ...
# 3           12        4201.00000              0.00238  ...
# 4           12        8228.38139                  NaN  ...
# ...        ...               ...                  ...  ...
# 18790464    23        8228.38139                  NaN  ...
# 18790465    23        3125.00000              0.00160  ...
# 18790466    23        8228.38139                  NaN  ...
# 18790467    23        3640.00000              0.00137  ...
# 18790468    23      270511.00000              0.00127  ...
#
#           download_rate_by_ip_device_app  click_freq_by_ip_device_os  \
# 0                                0.00000                    27.10545
# 1                                0.00218                   752.53691
# 2                                0.00000                  1490.00000
# 3                                0.00000                   921.00000
# 4                                    NaN                   520.19583
# ...                                  ...                         ...
# 18790464                             NaN                   520.19583
# 18790465                         0.00000                   170.00000
# 18790466                             NaN                   520.19583
# 18790467                         0.00143                   525.93625
# 18790468                         0.00000                   748.00000
#
#           download_rate_by_ip_device_os  click_freq_by_ip_device_os_hour  \
# 0                               0.00000                          6.46182
# 1                               0.00155                         45.42412
# 2                               0.00201                        104.00000
# 3                               0.00326                         19.00000
# 4                                   NaN                         36.51880
# ...                                 ...                              ...
# 18790464                            NaN                         36.51880
# 18790465                        0.00000                         28.00000
# 18790466                            NaN                         36.51880
# 18790467                        0.00112                         35.69482
# 18790468                        0.00000                         72.00000
#
#           download_rate_by_ip_device_os_hour  nunique_channel_per_ip  \
# 0                                    0.00000                67.00000
# 1                                    0.00169               118.00000
# 2                                    0.00000               114.00000
# 3                                    0.00000               113.00000
# 4                                        NaN                98.54734
# ...                                      ...                     ...
# 18790464                                 NaN                98.54734
# 18790465                             0.00000               107.00000
# 18790466                                 NaN                98.54734
# 18790467                             0.00118               110.00000
# 18790468                             0.00000               139.00000
#
#           nunique_device_per_ip  nunique_app_per_ip  nunique_os_per_ip  \
# 0                       4.00000            27.00000           31.00000
# 1                      10.00000            63.00000           54.00000
# 2                       7.00000            52.00000           44.00000
# 3                       5.00000            48.00000           43.00000
# 4                       8.27912            45.63491           44.08737
# ...                         ...                 ...                ...
# 18790464                8.27912            45.63491           44.08737
# 18790465                7.00000            52.00000           48.00000
# 18790466                8.27912            45.63491           44.08737
# 18790467                6.00000            45.00000           43.00000
# 18790468               58.00000           138.00000          150.00000
#
#           nunique_channel_per_app
# 0                        28.10182
# 1                        28.12297
# 2                         8.00000
# 3                        30.00000
# 4                        27.86215
# ...                           ...
# 18790464                 27.86215
# 18790465                  8.00000
# 18790466                 27.86215
# 18790467                 28.08845
# 18790468                 33.00000
#
# [18790469 rows x 35 columns]

# %% [markdown]
# ## Save result

# %%
pd.read_csv("../input/sample_submission_adtracking.csv")
# Out:
#           click_id  is_attributed
# 0                0              0
# 1                1              0
# 2                2              0
# 3                3              0
# 4                4              0
# ...            ...            ...
# 18790464  18790464              0
# 18790465  18790465              0
# 18790466  18790467              0
# 18790467  18790466              0
# 18790468  18790468              0
#
# [18790469 rows x 2 columns]

# %%
unseen_data_withfeature.to_feather("../processing/unseen_withfeature.feather")
